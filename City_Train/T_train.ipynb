# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the dataset
df_train_T = pd.read_csv("/content/T_train.csv")
df_test_T = pd.read_csv("/content/T_test.csv")

# %%
df_train_T
# Out:
#                Unnamed: 0  weather  temperature  pressure  humidity  \
# 0     2014-05-01 00:00:00      0.0     0.568627  0.475410      0.56
# 1     2014-05-01 01:00:00      0.0     0.549020  0.475410      0.59
# 2     2014-05-01 02:00:00      0.0     0.549020  0.475410      0.61
# 3     2014-05-01 03:00:00      0.0     0.509804  0.459016      0.66
# 4     2014-05-01 04:00:00      0.0     0.529412  0.459016      0.63
# ...                   ...      ...          ...       ...       ...
# 7002  2015-02-16 18:00:00      0.0     0.372549  0.606557      0.27
# 7003  2015-02-16 19:00:00      0.0     0.372549  0.639344      0.28
# 7004  2015-02-16 20:00:00      0.0     0.372549  0.639344      0.28
# 7005  2015-02-16 21:00:00      0.0     0.352941  0.639344      0.26
# 7006  2015-02-16 22:00:00      0.0     0.352941  0.639344      0.26
#
#       wind_speed  wind_direction  PM10_Concentration  NO2_Concentration  \
# 0       0.133333            23.0            0.164141           0.123932
# 1       0.116667            23.0            0.194444           0.136752
# 2       0.200000             3.0            0.190657           0.183761
# 3       0.058333            23.0            0.190657           0.162393
# 4       0.083333            23.0            0.175505           0.200855
# ...          ...             ...                 ...                ...
# 7002    0.196759            14.0            0.200758           0.072650
# 7003    0.133333            14.0            0.171717           0.085470
# 7004    0.133333            14.0            0.126263           0.115385
# 7005    0.091667            14.0            0.084596           0.141026
# 7006    0.091667            14.0            0.077020           0.128205
#
#       CO_Concentration  O3_Concentration  SO2_Concentration  \
# 0             0.088222          0.277929           0.114228
# 1             0.116895          0.245232           0.114228
# 2             0.149978          0.231608           0.148297
# 3             0.107442          0.258856           0.156313
# 4             0.112988          0.217984           0.198397
# ...                ...               ...                ...
# 7002          0.071145          0.062670           0.074148
# 7003          0.074611          0.046322           0.060120
# 7004          0.090995          0.038147           0.094188
# 7005          0.080030          0.029973           0.106212
# 7006          0.073035          0.032698           0.082164
#
#       PM25_Concentration
# 0                   81.0
# 1                   88.0
# 2                   98.0
# 3                  117.0
# 4                  109.0
# ...                  ...
# 7002                43.0
# 7003                35.0
# 7004                39.0
# 7005                36.0
# 7006                28.0
#
# [7007 rows x 13 columns]

# %%
df_train_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7007 entries, 0 to 7006
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          7007 non-null   object
#  1   weather             7007 non-null   float64
#  2   temperature         7007 non-null   float64
#  3   pressure            7007 non-null   float64
#  4   humidity            7007 non-null   float64
#  5   wind_speed          7007 non-null   float64
#  6   wind_direction      7007 non-null   float64
#  7   PM10_Concentration  7007 non-null   float64
#  8   NO2_Concentration   7007 non-null   float64
#  9   CO_Concentration    7007 non-null   float64
#  10  O3_Concentration    7007 non-null   float64
#  11  SO2_Concentration   7007 non-null   float64
#  12  PM25_Concentration  7007 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 711.8+ KB

# %%
print("Shape of train data:" + str(df_train_T.shape))
print("Shape of test data:" + str(df_test_T.shape))
# Out:
# Shape of train data:(7007, 13)
# Shape of test data:(1729, 13)

# %%
train_arr = df_train_T
test_arr = df_test_T

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'column_to_drop' is the column you want to drop
column_to_drop = 'Unnamed: 0'

# Dropping the column
df_train_T = train_arr.drop(column_to_drop, axis=1)
df_test_T = test_arr.drop(column_to_drop, axis=1)

# %%
X_train = df_train_T[['weather', 'temperature', 'pressure', 'humidity', 'wind_speed',
       'wind_direction', 'PM10_Concentration', 'NO2_Concentration',
       'CO_Concentration', 'O3_Concentration', 'SO2_Concentration']]

# %%
y_train = df_train_T[['PM25_Concentration']]

# %%
X_test = df_test_T[['weather', 'temperature', 'pressure', 'humidity', 'wind_speed',
       'wind_direction', 'PM10_Concentration', 'NO2_Concentration',
       'CO_Concentration', 'O3_Concentration', 'SO2_Concentration']]

# %%
y_train = df_train_T[['PM25_Concentration']]

# %%
X_test = df_test_T[['weather', 'temperature', 'pressure', 'humidity', 'wind_speed',
       'wind_direction', 'PM10_Concentration', 'NO2_Concentration',
       'CO_Concentration', 'O3_Concentration', 'SO2_Concentration']]

# %%
y_test = df_test_T[['PM25_Concentration']]

# %%
num_columns = X_train.shape[1]
print("Number of columns:", num_columns)
# Out:
# Number of columns: 11

# %%
num_columns = y_test.shape[1]
print("Number of columns:", num_columns)
# Out:
# Number of columns: 1

# %%
print(y_test.shape)
# Out:
# (1729, 1)

# %%
print(y_train.shape)
# Out:
# (7007, 1)

# %%
print(X_train)
# Out:
#       weather  temperature  pressure  humidity  wind_speed  wind_direction  \
# 0         0.0     0.568627  0.475410      0.56    0.133333            23.0
# 1         0.0     0.549020  0.475410      0.59    0.116667            23.0
# 2         0.0     0.549020  0.475410      0.61    0.200000             3.0
# 3         0.0     0.509804  0.459016      0.66    0.058333            23.0
# 4         0.0     0.529412  0.459016      0.63    0.083333            23.0
# ...       ...          ...       ...       ...         ...             ...
# 7002      0.0     0.372549  0.606557      0.27    0.196759            14.0
# 7003      0.0     0.372549  0.639344      0.28    0.133333            14.0
# 7004      0.0     0.372549  0.639344      0.28    0.133333            14.0
# 7005      0.0     0.352941  0.639344      0.26    0.091667            14.0
# 7006      0.0     0.352941  0.639344      0.26    0.091667            14.0
#
#       PM10_Concentration  NO2_Concentration  CO_Concentration  \
# 0               0.164141           0.123932          0.088222
# 1               0.194444           0.136752          0.116895
# 2               0.190657           0.183761          0.149978
# 3               0.190657           0.162393          0.107442
# 4               0.175505           0.200855          0.112988
# ...                  ...                ...               ...
# 7002            0.200758           0.072650          0.071145
# 7003            0.171717           0.085470          0.074611
# 7004            0.126263           0.115385          0.090995
# 7005            0.084596           0.141026          0.080030
# 7006            0.077020           0.128205          0.073035
#
#       O3_Concentration  SO2_Concentration
# 0             0.277929           0.114228
# 1             0.245232           0.114228
# 2             0.231608           0.148297
# 3             0.258856           0.156313
# 4             0.217984           0.198397
# ...                ...                ...
# 7002          0.062670           0.074148
# 7003          0.046322           0.060120
# 7004          0.038147           0.094188
# 7005          0.029973           0.106212
# 7006          0.032698           0.082164
#
# [7007 rows x 11 columns]

# %%
print(y_train)
# Out:
#       PM25_Concentration
# 0                   81.0
# 1                   88.0
# 2                   98.0
# 3                  117.0
# 4                  109.0
# ...                  ...
# 7002                43.0
# 7003                35.0
# 7004                39.0
# 7005                36.0
# 7006                28.0
#
# [7007 rows x 1 columns]

# %%
print(X_test)
# Out:
#       weather  temperature  pressure  humidity  wind_speed  wind_direction  \
# 0         0.0     0.254902  0.655738      0.99    0.083333            24.0
# 1         0.0     0.352941  0.639344      0.26    0.091667            14.0
# 2         0.0     0.352941  0.639344      0.26    0.091667            14.0
# 3         0.0     0.352941  0.639344      0.26    0.091667            14.0
# 4         0.0     0.352941  0.639344      0.26    0.091667            14.0
# ...       ...          ...       ...       ...         ...             ...
# 1724      0.0     0.656863  0.508197      0.58    0.050926            23.0
# 1725      0.0     0.656863  0.508197      0.58    0.050926            23.0
# 1726      0.0     0.619608  0.524590      0.72    0.032407            23.0
# 1727      0.0     0.596078  0.508197      0.84    0.030093            23.0
# 1728      0.0     0.496078  0.573770      0.99    0.023148            13.0
#
#       PM10_Concentration  NO2_Concentration  CO_Concentration  \
# 0               0.107323           0.175214          0.079778
# 1               0.104798           0.205128          0.087907
# 2               0.128788           0.260684          0.109522
# 3               0.109848           0.175214          0.100195
# 4               0.113636           0.166667          0.101645
# ...                  ...                ...               ...
# 1724            0.111111           0.038462          0.036486
# 1725            0.111111           0.038462          0.036486
# 1726            0.141414           0.085470          0.043355
# 1727            0.223485           0.094017          0.150986
# 1728            0.164141           0.094017          0.094902
#
#       O3_Concentration  SO2_Concentration
# 0             0.024523           0.082164
# 1             0.019074           0.076152
# 2             0.013624           0.070140
# 3             0.019074           0.038076
# 4             0.019074           0.036072
# ...                ...                ...
# 1724          0.395095           0.012024
# 1725          0.395095           0.012024
# 1726          0.239782           0.012024
# 1727          0.185286           0.012024
# 1728          0.149864           0.012024
#
# [1729 rows x 11 columns]

# %%
print(y_test)
# Out:
#       PM25_Concentration
# 0                   23.0
# 1                   34.0
# 2                   47.0
# 3                   55.0
# 4                   40.0
# ...                  ...
# 1724                68.0
# 1725                68.0
# 1726                73.0
# 1727                81.0
# 1728                89.0
#
# [1729 rows x 1 columns]

# %%
import numpy as np

# Assuming 'y_train' is a DataFrame
y_train_array = y_train.to_numpy()

# Reshape the NumPy array
y_train_reshaped = y_train_array.reshape(-1, 1)

# %%
# Prepare sequences for multistep forecasting
def create_sequences(X_train,y_train, n_steps_in, n_steps_out):
    X, y = [], []
    for i in range(len(X_train) - n_steps_in - n_steps_out):
        X.append(X_train[i:i + n_steps_in])
        y.append(y_train[i + n_steps_in:i + n_steps_in + n_steps_out])
    return np.array(X), np.array(y)

# %%
n_steps_in = 12 # Number of time steps as input
n_steps_out = 5  # Number of time steps to predict ahead

X_train_predict, y_train_predict = create_sequences(X_train,y_train, n_steps_in, n_steps_out)
X_test_predict, y_test_predict = create_sequences(X_test, y_test, n_steps_in, n_steps_out)

# %%
#Importing the necessary components to define our model

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
from keras.losses import MeanSquaredError

# defining the stacked LSTM model
model = Sequential(name='LSTM-Model')
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(12, 11), name="LSTM_1"))
model.add(LSTM(100, activation='relu', return_sequences=False, name="LSTM_2"))  # Change return_sequences if needed
model.add(Dense(1, name="DENSE_1"))  # Adjust units according to your output dimensions

# Compile the model with mean squared error loss for multidimensional output
model.compile(optimizer='adam', loss=MeanSquaredError())

model.summary()
# Out:
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM_1 (LSTM)               (None, 12, 100)           44800
#
#  LSTM_2 (LSTM)               (None, 100)               80400
#
#  DENSE_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 125301 (489.46 KB)
# Trainable params: 125301 (489.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Plotting the layer structure
from keras.utils import plot_model
plot_model(model,show_shapes=True,show_layer_names=True,rankdir="TB",dpi=96)

# %%
print(X_test_predict.shape)
# Out:
# (1712, 12, 11)

# %%
print(X_train_predict.shape)
# Out:
# (6990, 12, 11)

# %%
print(y_train_predict.shape)
# Out:
# (6990, 5, 1)

# %%
print(y_test_predict)
# Out:
# [[[ 26.]
#   [ 28.]
#   [ 31.]
#   [ 59.]
#   [ 88.]]
#
#  [[ 28.]
#   [ 31.]
#   [ 59.]
#   [ 88.]
#   [ 63.]]
#
#  [[ 31.]
#   [ 59.]
#   [ 88.]
#   [ 63.]
#   [ 52.]]
#
#  ...
#
#  [[100.]
#   [ 77.]
#   [ 70.]
#   [ 68.]
#   [ 68.]]
#
#  [[ 77.]
#   [ 70.]
#   [ 68.]
#   [ 68.]
#   [ 73.]]
#
#  [[ 70.]
#   [ 68.]
#   [ 68.]
#   [ 73.]
#   [ 81.]]]

# %%
history = model.fit(X_train_predict, y_train_predict, epochs=50, batch_size=90, verbose=2, shuffle=False)


# from keras.callbacks import EarlyStopping

# # Define the early stopping criteria
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

# # Assuming 'X_train' and 'y_train' are your training data
# # Fit the model with early stopping
# history = model.fit(X_train_predict, y_train_predict, epochs=100, validation_split=0.2, callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/50
# 78/78 - 6s - loss: 5948.9751 - 6s/epoch - 79ms/step
# Epoch 2/50
# 78/78 - 4s - loss: 5302.9971 - 4s/epoch - 48ms/step
# Epoch 3/50
# 78/78 - 5s - loss: 5199.8003 - 5s/epoch - 62ms/step
# Epoch 4/50
# 78/78 - 3s - loss: 5155.8994 - 3s/epoch - 39ms/step
# Epoch 5/50
# 78/78 - 3s - loss: 5113.0527 - 3s/epoch - 39ms/step
# Epoch 6/50
# 78/78 - 3s - loss: 5284.2788 - 3s/epoch - 42ms/step
# Epoch 7/50
# 78/78 - 5s - loss: 5121.9341 - 5s/epoch - 65ms/step
# Epoch 8/50
# 78/78 - 3s - loss: 5047.6172 - 3s/epoch - 38ms/step
# Epoch 9/50
# 78/78 - 3s - loss: 5213.5732 - 3s/epoch - 40ms/step
# Epoch 10/50
# 78/78 - 3s - loss: 5235.3354 - 3s/epoch - 41ms/step
# Epoch 11/50
# 78/78 - 5s - loss: 5405.9009 - 5s/epoch - 68ms/step
# Epoch 12/50
# 78/78 - 3s - loss: 5427.9609 - 3s/epoch - 40ms/step
# Epoch 13/50
# 78/78 - 3s - loss: 5442.3696 - 3s/epoch - 40ms/step
# Epoch 14/50
# 78/78 - 3s - loss: 5425.3125 - 3s/epoch - 39ms/step
# Epoch 15/50
# 78/78 - 5s - loss: 5432.7241 - 5s/epoch - 68ms/step
# Epoch 16/50
# 78/78 - 3s - loss: 5426.3447 - 3s/epoch - 40ms/step
# Epoch 17/50
# 78/78 - 3s - loss: 5381.4570 - 3s/epoch - 40ms/step
# Epoch 18/50
# 78/78 - 3s - loss: 5362.4385 - 3s/epoch - 42ms/step
# Epoch 19/50
# 78/78 - 5s - loss: 5322.0210 - 5s/epoch - 68ms/step
# Epoch 20/50
# 78/78 - 3s - loss: 5286.5317 - 3s/epoch - 40ms/step
# Epoch 21/50
# 78/78 - 3s - loss: 5236.1226 - 3s/epoch - 39ms/step
# Epoch 22/50
# 78/78 - 3s - loss: 5035.3647 - 3s/epoch - 44ms/step
# Epoch 23/50
# 78/78 - 5s - loss: 5091.7363 - 5s/epoch - 67ms/step
# Epoch 24/50
# 78/78 - 3s - loss: 5111.6045 - 3s/epoch - 41ms/step
# Epoch 25/50
# 78/78 - 3s - loss: 5080.3491 - 3s/epoch - 41ms/step
# Epoch 26/50
# 78/78 - 3s - loss: 5062.2056 - 3s/epoch - 44ms/step
# Epoch 27/50
# 78/78 - 5s - loss: 5002.4028 - 5s/epoch - 65ms/step
# Epoch 28/50
# 78/78 - 3s - loss: 5004.1191 - 3s/epoch - 41ms/step
# Epoch 29/50
# 78/78 - 3s - loss: 4892.0522 - 3s/epoch - 41ms/step
# Epoch 30/50
# 78/78 - 4s - loss: 4866.6802 - 4s/epoch - 49ms/step
# Epoch 31/50
# 78/78 - 6s - loss: 4801.5288 - 6s/epoch - 72ms/step
# Epoch 32/50
# 78/78 - 5s - loss: 4779.6216 - 5s/epoch - 59ms/step
# Epoch 33/50
# 78/78 - 3s - loss: 4675.0879 - 3s/epoch - 40ms/step
# Epoch 34/50
# 78/78 - 5s - loss: 4675.9614 - 5s/epoch - 68ms/step
# Epoch 35/50
# 78/78 - 3s - loss: 4635.2378 - 3s/epoch - 40ms/step
# Epoch 36/50
# 78/78 - 3s - loss: 4591.9038 - 3s/epoch - 40ms/step
# Epoch 37/50
# 78/78 - 3s - loss: 5735.3247 - 3s/epoch - 39ms/step
# Epoch 38/50
# 78/78 - 5s - loss: 4188.6294 - 5s/epoch - 68ms/step
# Epoch 39/50
# 78/78 - 3s - loss: 4147.5298 - 3s/epoch - 40ms/step
# Epoch 40/50
# 78/78 - 3s - loss: 4631.1694 - 3s/epoch - 40ms/step
# Epoch 41/50
# 78/78 - 3s - loss: 4666.3833 - 3s/epoch - 40ms/step
# Epoch 42/50
# 78/78 - 5s - loss: 4649.4961 - 5s/epoch - 68ms/step
# Epoch 43/50
# 78/78 - 3s - loss: 4697.3403 - 3s/epoch - 40ms/step
# Epoch 44/50
# 78/78 - 3s - loss: 4651.9014 - 3s/epoch - 39ms/step
# Epoch 45/50
# 78/78 - 3s - loss: 4573.6011 - 3s/epoch - 40ms/step
# Epoch 46/50
# 78/78 - 5s - loss: 4512.5708 - 5s/epoch - 69ms/step
# Epoch 47/50
# 78/78 - 3s - loss: 4382.5820 - 3s/epoch - 39ms/step
# Epoch 48/50
# 78/78 - 3s - loss: 4319.5146 - 3s/epoch - 40ms/step
# Epoch 49/50
# 78/78 - 3s - loss: 4418.7041 - 3s/epoch - 40ms/step
# Epoch 50/50
# 78/78 - 5s - loss: 4301.8687 - 5s/epoch - 68ms/step

# %%
y_pred = model.predict(X_test_predict)
# Out:
# 54/54 [==============================] - 1s 8ms/step

# %%
print(y_pred.shape)
# Out:
# (1712, 1)

# %%
print(y_pred)
# Out:
# [[ 96.641365]
#  [ 90.30685 ]
#  [ 89.183266]
#  ...
#  [118.61552 ]
#  [117.99382 ]
#  [118.00673 ]]

# %%
for prediction in y_pred:
    last_value = prediction[-1]  # Assuming the last column is the target variable
    print(last_value)
# Out:
# 96.641365
# 90.30685
# 89.183266
# 87.191536
# 87.2168
# 86.48204
# 85.796005
# 84.89483
# 85.26865
# 86.16786
# 87.17811
# 91.7914
# 94.20512
# 98.04303
# 93.26912
# 91.6597
# 85.78913
# 85.096176
# 86.831726
# 87.325356
# 88.478355
# 91.13899
# 97.416046
# 105.88256
# 110.042435
# 113.45287
# 114.75376
# 114.80836
# 114.19065
# 112.22926
# 109.7363
# 106.139755
# 100.138084
# 93.32904
# 90.11412
# 83.67172
# 73.69518
# 68.33971
# 68.48049
# 72.13651
# 75.79875
# 79.89785
# 85.35738
# 89.567
# 94.49439
# 100.709564
# 107.68942
# 114.38415
# 120.54223
# 117.71704
# 109.06364
# 99.67133
# 99.35105
# 98.7317
# 97.66957
# 94.85497
# 91.18437
# 91.51696
# 96.65201
# 106.48381
# 116.01819
# 125.55229
# 138.09071
# 121.23313
# 103.883316
# 87.834564
# 74.48925
# 65.78266
# 63.115173
# 67.418434
# 68.42466
# 76.5898
# 82.3137
# 84.593315
# 98.48301
# 115.54317
# 126.06364
# 146.82736
# 144.3959
# 136.44456
# 149.79613
# 160.87057
# 167.71198
# 165.5339
# 170.60738
# 163.96532
# 178.82036
# 178.09464
# 186.72781
# 199.10184
# 207.32193
# 202.96613
# 197.75136
# 190.7279
# 159.51965
# 124.6896
# 110.67914
# 134.77911
# 139.62247
# 148.63316
# 157.63037
# 154.63034
# 153.11058
# 153.2099
# 153.87968
# 145.81364
# 134.61868
# 120.646774
# 106.85495
# 125.684235
# 149.27882
# 157.36038
# 161.742
# 162.1419
# 160.34802
# 152.2301
# 141.48598
# 134.55711
# 125.024574
# 115.11491
# 116.58857
# 103.14745
# 102.20038
# 101.12085
# 99.74103
# 97.06144
# 95.08076
# 92.80023
# 90.46266
# 88.77867
# 87.69848
# 87.27501
# 87.97006
# 88.97968
# 91.71507
# 106.25212
# 125.74515
# 135.90282
# 139.8929
# 142.05035
# 144.4275
# 145.0907
# 144.95605
# 142.03479
# 137.63324
# 135.35449
# 157.11914
# 112.02714
# 118.07704
# 119.838776
# 117.92434
# 115.409546
# 111.67846
# 117.22266
# 126.52932
# 128.43016
# 120.59837
# 117.32447
# 116.42375
# 125.10247
# 137.89226
# 130.07329
# 120.37515
# 113.53759
# 115.27298
# 129.65527
# 134.94415
# 146.3099
# 187.77995
# 115.13662
# 116.975685
# 121.27663
# 124.18687
# 126.695305
# 125.51992
# 124.14799
# 123.60461
# 122.73634
# 126.1112
# 131.32968
# 134.65863
# 136.73761
# 99.95589
# 92.77309
# 85.402534
# 79.501274
# 73.85038
# 70.4497
# 68.743835
# 79.25026
# 90.000175
# 98.51655
# 107.06157
# 119.194405
# 119.31201
# 118.36952
# 118.61685
# 132.15361
# 141.95099
# 145.89801
# 146.1097
# 134.84225
# 132.98187
# 130.66304
# 123.7298
# 121.822716
# 120.97984
# 118.28227
# 105.88346
# 94.13232
# 91.605995
# 95.74992
# 92.99097
# 110.24774
# 111.51572
# 124.11402
# 126.97222
# 125.09156
# 123.050735
# 120.60916
# 118.07765
# 118.02381
# 119.02511
# 135.98167
# 136.54906
# 134.69765
# 127.666565
# 129.28717
# 123.641396
# 121.04306
# 116.83496
# 109.10897
# 111.06482
# 101.72331
# 97.54843
# 115.25853
# 107.46748
# 105.205696
# 113.85995
# 107.86767
# 122.03465
# 111.34054
# 102.6445
# 102.91415
# 106.028534
# 117.85493
# 87.11278
# 94.842545
# 112.00396
# 107.75065
# 101.05427
# 128.34875
# 115.707466
# 102.04397
# 97.87425
# 109.979004
# 102.35092
# 91.94992
# 89.60502
# 94.35608
# 94.79225
# 89.24995
# 96.81995
# 89.773705
# 103.22893
# 114.11469
# 113.8433
# 114.563324
# 129.89993
# 123.15079
# 117.68024
# 119.381165
# 108.94431
# 98.399506
# 138.19669
# 141.14793
# 133.78778
# 124.87956
# 118.5707
# 116.17011
# 115.678665
# 110.744354
# 112.15287
# 110.48328
# 111.71795
# 119.64272
# 142.62099
# 129.11737
# 127.3365
# 128.982
# 128.75177
# 127.26583
# 125.46855
# 124.87684
# 122.65465
# 119.34475
# 117.65316
# 115.122086
# 116.83855
# 108.89386
# 107.61332
# 106.57413
# 105.33803
# 104.273026
# 104.63041
# 106.05627
# 108.11084
# 111.24246
# 114.48637
# 118.30728
# 125.22092
# 129.39313
# 132.28897
# 135.42273
# 137.45166
# 140.78322
# 138.58966
# 141.8626
# 148.15822
# 149.58414
# 149.54608
# 145.27055
# 144.24721
# 146.06369
# 147.95084
# 153.88724
# 156.42908
# 155.32996
# 154.83801
# 151.93578
# 148.07837
# 143.37259
# 138.96808
# 130.91106
# 125.718
# 120.8579
# 121.70872
# 140.52393
# 138.09813
# 134.70125
# 134.49704
# 134.11906
# 132.2538
# 130.07729
# 127.29194
# 123.42821
# 123.837616
# 116.24119
# 115.85782
# 115.19797
# 113.49482
# 111.681046
# 109.501724
# 107.816376
# 106.37242
# 106.001076
# 106.51126
# 108.114494
# 109.214615
# 111.78178
# 114.41093
# 116.829666
# 119.68275
# 122.38973
# 122.92096
# 123.86055
# 123.37639
# 121.478935
# 118.582596
# 114.81461
# 113.64573
# 116.8675
# 117.284225
# 118.78951
# 119.11117
# 118.61552
# 117.99382
# 118.00673

# %%
print(y_test.shape)
# Out:
# (1729, 1)

# %%
print(y_test.shape)
# Out:
# (1729, 1)

# %%
y_test = y_test[n_steps_in: -n_steps_out]

# %%
print(y_test.shape)
# Out:
# (1712, 1)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

mean_squared_error(y_test, y_pred)
# Out:
# 3140.884152440248

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

mean_absolute_error(y_test, y_pred)
# Out:
# 45.63171940206367
