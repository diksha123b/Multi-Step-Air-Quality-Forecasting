# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the dataset
df_train_S = pd.read_csv("/content/S_train.csv")
df_test_S = pd.read_csv("/content/S_test.csv")

# %%
df_train_S
# Out:
#                Unnamed: 0  weather  temperature  pressure  humidity  \
# 0     2014-10-29 11:00:00      1.0     0.794118  0.540984      0.53
# 1     2014-10-29 12:00:00      1.0     0.803922  0.524590      0.53
# 2     2014-10-29 13:00:00      1.0     0.811765  0.508197      0.52
# 3     2014-10-29 14:00:00      1.0     0.819608  0.508197      0.50
# 4     2014-10-29 15:00:00      1.0     0.819608  0.491803      0.50
# ...                   ...      ...          ...       ...       ...
# 3518  2015-03-25 01:00:00      2.0     0.576471  0.647541      0.76
# 3519  2015-03-25 02:00:00      2.0     0.576471  0.639344      0.75
# 3520  2015-03-25 03:00:00      2.0     0.576471  0.627869      0.74
# 3521  2015-03-25 04:00:00      2.0     0.574510  0.626230      0.74
# 3522  2015-03-25 05:00:00      2.0     0.570588  0.631148      0.76
#
#       wind_speed  wind_direction  PM10_Concentration  NO2_Concentration  \
# 0       0.034722            13.0            0.083333           0.111111
# 1       0.055556            13.0            0.050505           0.068376
# 2       0.034722            13.0            0.050505           0.055556
# 3       0.041667            13.0            0.039141           0.059829
# 4       0.037037            13.0            0.075758           0.076923
# ...          ...             ...                 ...                ...
# 3518    0.034722            13.0            0.021465           0.034188
# 3519    0.020833            13.0            0.031566           0.029915
# 3520    0.020833            13.0            0.035354           0.029915
# 3521    0.013889            14.0            0.061869           0.034188
# 3522    0.013889            13.0            0.050505           0.029915
#
#       CO_Concentration  O3_Concentration  SO2_Concentration  \
# 0             0.057218          0.193460           0.014028
# 1             0.057975          0.201635           0.010020
# 2             0.054005          0.204360           0.010020
# 3             0.052618          0.188011           0.008016
# 4             0.053627          0.190736           0.010020
# ...                ...               ...                ...
# 3518          0.037810          0.272480           0.006012
# 3519          0.038440          0.253406           0.008016
# 3520          0.039700          0.242507           0.010020
# 3521          0.039700          0.234332           0.010020
# 3522          0.041591          0.226158           0.010020
#
#       PM25_Concentration
# 0                   29.0
# 1                   29.0
# 2                   28.0
# 3                   26.0
# 4                   26.0
# ...                  ...
# 3518                17.0
# 3519                18.0
# 3520                20.0
# 3521                21.0
# 3522                24.0
#
# [3523 rows x 13 columns]

# %%
df_train_S.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          3523 non-null   object
#  1   weather             3523 non-null   float64
#  2   temperature         3523 non-null   float64
#  3   pressure            3523 non-null   float64
#  4   humidity            3523 non-null   float64
#  5   wind_speed          3523 non-null   float64
#  6   wind_direction      3523 non-null   float64
#  7   PM10_Concentration  3523 non-null   float64
#  8   NO2_Concentration   3523 non-null   float64
#  9   CO_Concentration    3523 non-null   float64
#  10  O3_Concentration    3523 non-null   float64
#  11  SO2_Concentration   3523 non-null   float64
#  12  PM25_Concentration  3523 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 357.9+ KB

# %%
print("Shape of train data:" + str(df_train_S.shape))
print("Shape of test data:" + str(df_test_S.shape))
# Out:
# Shape of train data:(3523, 13)
# Shape of test data:(858, 13)

# %%
train_arr = df_train_S
test_arr = df_test_S

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'column_to_drop' is the column you want to drop
column_to_drop = 'Unnamed: 0'

# Dropping the column
df_train_S = train_arr.drop(column_to_drop, axis=1)
df_test_S = test_arr.drop(column_to_drop, axis=1)

# %%
X_train = df_train_S[['weather', 'temperature', 'pressure', 'humidity', 'wind_speed',
       'wind_direction', 'PM10_Concentration', 'NO2_Concentration',
       'CO_Concentration', 'O3_Concentration', 'SO2_Concentration']]

# %%
y_train = df_train_S[['PM25_Concentration']]

# %%
X_test = df_test_S[['weather', 'temperature', 'pressure', 'humidity', 'wind_speed',
       'wind_direction', 'PM10_Concentration', 'NO2_Concentration',
       'CO_Concentration', 'O3_Concentration', 'SO2_Concentration']]

# %%
y_test = df_test_S[['PM25_Concentration']]

# %%
num_columns = X_train.shape[1]
print("Number of columns:", num_columns)
# Out:
# Number of columns: 11

# %%
num_columns = y_test.shape[1]
print("Number of columns:", num_columns)
# Out:
# Number of columns: 1

# %%
print(y_test.shape)
# Out:
# (858, 1)

# %%
print(y_train.shape)
# Out:
# (3523, 1)

# %%
print(X_train)
# Out:
#       weather  temperature  pressure  humidity  wind_speed  wind_direction  \
# 0         1.0     0.794118  0.540984      0.53    0.034722            13.0
# 1         1.0     0.803922  0.524590      0.53    0.055556            13.0
# 2         1.0     0.811765  0.508197      0.52    0.034722            13.0
# 3         1.0     0.819608  0.508197      0.50    0.041667            13.0
# 4         1.0     0.819608  0.491803      0.50    0.037037            13.0
# ...       ...          ...       ...       ...         ...             ...
# 3518      2.0     0.576471  0.647541      0.76    0.034722            13.0
# 3519      2.0     0.576471  0.639344      0.75    0.020833            13.0
# 3520      2.0     0.576471  0.627869      0.74    0.020833            13.0
# 3521      2.0     0.574510  0.626230      0.74    0.013889            14.0
# 3522      2.0     0.570588  0.631148      0.76    0.013889            13.0
#
#       PM10_Concentration  NO2_Concentration  CO_Concentration  \
# 0               0.083333           0.111111          0.057218
# 1               0.050505           0.068376          0.057975
# 2               0.050505           0.055556          0.054005
# 3               0.039141           0.059829          0.052618
# 4               0.075758           0.076923          0.053627
# ...                  ...                ...               ...
# 3518            0.021465           0.034188          0.037810
# 3519            0.031566           0.029915          0.038440
# 3520            0.035354           0.029915          0.039700
# 3521            0.061869           0.034188          0.039700
# 3522            0.050505           0.029915          0.041591
#
#       O3_Concentration  SO2_Concentration
# 0             0.193460           0.014028
# 1             0.201635           0.010020
# 2             0.204360           0.010020
# 3             0.188011           0.008016
# 4             0.190736           0.010020
# ...                ...                ...
# 3518          0.272480           0.006012
# 3519          0.253406           0.008016
# 3520          0.242507           0.010020
# 3521          0.234332           0.010020
# 3522          0.226158           0.010020
#
# [3523 rows x 11 columns]

# %%
print(y_train)
# Out:
#       PM25_Concentration
# 0                   29.0
# 1                   29.0
# 2                   28.0
# 3                   26.0
# 4                   26.0
# ...                  ...
# 3518                17.0
# 3519                18.0
# 3520                20.0
# 3521                21.0
# 3522                24.0
#
# [3523 rows x 1 columns]

# %%
print(X_test)
# Out:
#      weather  temperature  pressure  humidity  wind_speed  wind_direction  \
# 0        2.0     0.570588  0.631148      0.76    0.013889            13.0
# 1        2.0     0.570588  0.639344      0.75    0.013889            13.0
# 2        2.0     0.570588  0.639344      0.75    0.013889            13.0
# 3        2.0     0.601961  0.663934      0.71    0.034722            13.0
# 4        2.0     0.601961  0.670492      0.71    0.037037            14.0
# ..       ...          ...       ...       ...         ...             ...
# 853      4.0     0.752941  0.414754      0.79    0.020833            23.0
# 854      4.0     0.741176  0.427869      0.83    0.018519            23.0
# 855      4.0     0.737255  0.449180      0.81    0.013889            23.0
# 856      4.0     0.735294  0.459016      0.84    0.013889             3.0
# 857      4.0     0.735294  0.460656      0.82    0.013889             3.0
#
#      PM10_Concentration  NO2_Concentration  CO_Concentration  \
# 0              0.050505           0.029915          0.041591
# 1              0.074495           0.064103          0.042851
# 2              0.074495           0.064103          0.042851
# 3              0.113636           0.175214          0.047262
# 4              0.118687           0.226496          0.049783
# ..                  ...                ...               ...
# 853            0.073232           0.222222          0.063016
# 854            0.082071           0.239316          0.063016
# 855            0.063131           0.162393          0.063016
# 856            0.045455           0.106838          0.063016
# 857            0.045455           0.102564          0.063016
#
#      O3_Concentration  SO2_Concentration
# 0            0.226158           0.010020
# 1            0.182561           0.012024
# 2            0.182561           0.012024
# 3            0.119891           0.016032
# 4            0.098093           0.016032
# ..                ...                ...
# 853          0.029973           0.028056
# 854          0.008174           0.042084
# 855          0.027248           0.032064
# 856          0.065395           0.014028
# 857          0.062670           0.012024
#
# [858 rows x 11 columns]

# %%
print(y_test)
# Out:
#      PM25_Concentration
# 0                  24.0
# 1                  30.0
# 2                  30.0
# 3                  37.0
# 4                  39.0
# ..                  ...
# 853                22.0
# 854                25.0
# 855                20.0
# 856                16.0
# 857                16.0
#
# [858 rows x 1 columns]

# %%
import numpy as np

# Assuming 'y_train' is a DataFrame
y_train_array = y_train.to_numpy()

# Reshape the NumPy array
y_train_reshaped = y_train_array.reshape(-1, 1)

# %%
# Prepare sequences for multistep forecasting
def create_sequences(X_train,y_train, n_steps_in, n_steps_out):
    X, y = [], []
    for i in range(len(X_train) - n_steps_in - n_steps_out):
        X.append(X_train[i:i + n_steps_in])
        y.append(y_train[i + n_steps_in:i + n_steps_in + n_steps_out])
    return np.array(X), np.array(y)

# %%
n_steps_in = 12 # Number of time steps as input
n_steps_out = 5  # Number of time steps to predict ahead

X_train_predict, y_train_predict = create_sequences(X_train,y_train, n_steps_in, n_steps_out)
X_test_predict, y_test_predict = create_sequences(X_test, y_test, n_steps_in, n_steps_out)

# %%
#Importing the necessary components to define our model

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
from keras.losses import MeanSquaredError

# defining the stacked LSTM model
model = Sequential(name='LSTM-Model')
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(12, 11), name="LSTM_1"))
model.add(LSTM(100, activation='relu', return_sequences=False, name="LSTM_2"))  # Change return_sequences if needed
model.add(Dense(1, name="DENSE_1"))  # Adjust units according to your output dimensions

# Compile the model with mean squared error loss for multidimensional output
model.compile(optimizer='adam', loss=MeanSquaredError())

model.summary()
# Out:
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM_1 (LSTM)               (None, 12, 100)           44800
#
#  LSTM_2 (LSTM)               (None, 100)               80400
#
#  DENSE_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 125301 (489.46 KB)
# Trainable params: 125301 (489.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Plotting the layer structure
from keras.utils import plot_model
plot_model(model,show_shapes=True,show_layer_names=True,rankdir="TB",dpi=96)

# %%
print(X_test_predict.shape)
# Out:
# (841, 12, 11)

# %%
print(X_train_predict.shape)
# Out:
# (3506, 12, 11)

# %%
print(y_train_predict.shape)
# Out:
# (3506, 5, 1)

# %%
print(y_test_predict)
# Out:
# [[[58.]
#   [46.]
#   [46.]
#   [42.]
#   [42.]]
#
#  [[46.]
#   [46.]
#   [42.]
#   [42.]
#   [40.]]
#
#  [[46.]
#   [42.]
#   [42.]
#   [40.]
#   [43.]]
#
#  ...
#
#  [[27.]
#   [24.]
#   [21.]
#   [22.]
#   [25.]]
#
#  [[24.]
#   [21.]
#   [22.]
#   [25.]
#   [20.]]
#
#  [[21.]
#   [22.]
#   [25.]
#   [20.]
#   [16.]]]

# %%
history = model.fit(X_train_predict, y_train_predict, epochs=50, batch_size=90, verbose=2, shuffle=False)


# from keras.callbacks import EarlyStopping

# # Define the early stopping criteria
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

# # Assuming 'X_train' and 'y_train' are your training data
# # Fit the model with early stopping
# history = model.fit(X_train_predict, y_train_predict, epochs=100, validation_split=0.2, callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/50
# 39/39 - 5s - loss: 1007.5880 - 5s/epoch - 139ms/step
# Epoch 2/50
# 39/39 - 2s - loss: 588.4812 - 2s/epoch - 41ms/step
# Epoch 3/50
# 39/39 - 3s - loss: 630.7156 - 3s/epoch - 85ms/step
# Epoch 4/50
# 39/39 - 2s - loss: 632.4312 - 2s/epoch - 61ms/step
# Epoch 5/50
# 39/39 - 2s - loss: 620.4843 - 2s/epoch - 42ms/step
# Epoch 6/50
# 39/39 - 2s - loss: 589.9090 - 2s/epoch - 42ms/step
# Epoch 7/50
# 39/39 - 2s - loss: 627.5976 - 2s/epoch - 46ms/step
# Epoch 8/50
# 39/39 - 2s - loss: 589.3410 - 2s/epoch - 40ms/step
# Epoch 9/50
# 39/39 - 2s - loss: 565.7692 - 2s/epoch - 44ms/step
# Epoch 10/50
# 39/39 - 3s - loss: 527.9389 - 3s/epoch - 69ms/step
# Epoch 11/50
# 39/39 - 3s - loss: 516.9830 - 3s/epoch - 76ms/step
# Epoch 12/50
# 39/39 - 2s - loss: 507.2192 - 2s/epoch - 45ms/step
# Epoch 13/50
# 39/39 - 2s - loss: 481.8447 - 2s/epoch - 41ms/step
# Epoch 14/50
# 39/39 - 2s - loss: 457.7752 - 2s/epoch - 46ms/step
# Epoch 15/50
# 39/39 - 2s - loss: 451.2997 - 2s/epoch - 45ms/step
# Epoch 16/50
# 39/39 - 2s - loss: 448.4460 - 2s/epoch - 43ms/step
# Epoch 17/50
# 39/39 - 2s - loss: 443.7699 - 2s/epoch - 52ms/step
# Epoch 18/50
# 39/39 - 3s - loss: 412.9233 - 3s/epoch - 81ms/step
# Epoch 19/50
# 39/39 - 2s - loss: 421.5699 - 2s/epoch - 53ms/step
# Epoch 20/50
# 39/39 - 2s - loss: 392.1003 - 2s/epoch - 45ms/step
# Epoch 21/50
# 39/39 - 2s - loss: 392.8501 - 2s/epoch - 41ms/step
# Epoch 22/50
# 39/39 - 2s - loss: 371.7180 - 2s/epoch - 45ms/step
# Epoch 23/50
# 39/39 - 2s - loss: 366.9651 - 2s/epoch - 46ms/step
# Epoch 24/50
# 39/39 - 2s - loss: 356.6216 - 2s/epoch - 42ms/step
# Epoch 25/50
# 39/39 - 3s - loss: 346.0445 - 3s/epoch - 84ms/step
# Epoch 26/50
# 39/39 - 2s - loss: 340.4828 - 2s/epoch - 61ms/step
# Epoch 27/50
# 39/39 - 2s - loss: 333.0761 - 2s/epoch - 42ms/step
# Epoch 28/50
# 39/39 - 2s - loss: 326.8047 - 2s/epoch - 42ms/step
# Epoch 29/50
# 39/39 - 2s - loss: 322.2723 - 2s/epoch - 45ms/step
# Epoch 30/50
# 39/39 - 2s - loss: 316.8907 - 2s/epoch - 48ms/step
# Epoch 31/50
# 39/39 - 2s - loss: 310.7850 - 2s/epoch - 43ms/step
# Epoch 32/50
# 39/39 - 3s - loss: 310.7852 - 3s/epoch - 77ms/step
# Epoch 33/50
# 39/39 - 3s - loss: 303.1110 - 3s/epoch - 75ms/step
# Epoch 34/50
# 39/39 - 2s - loss: 302.1999 - 2s/epoch - 42ms/step
# Epoch 35/50
# 39/39 - 2s - loss: 300.2889 - 2s/epoch - 43ms/step
# Epoch 36/50
# 39/39 - 2s - loss: 289.2157 - 2s/epoch - 45ms/step
# Epoch 37/50
# 39/39 - 2s - loss: 287.1793 - 2s/epoch - 44ms/step
# Epoch 38/50
# 39/39 - 2s - loss: 296.4495 - 2s/epoch - 44ms/step
# Epoch 39/50
# 39/39 - 2s - loss: 304.9076 - 2s/epoch - 57ms/step
# Epoch 40/50
# 39/39 - 3s - loss: 287.8944 - 3s/epoch - 82ms/step
# Epoch 41/50
# 39/39 - 2s - loss: 269.5143 - 2s/epoch - 45ms/step
# Epoch 42/50
# 39/39 - 2s - loss: 293.0738 - 2s/epoch - 48ms/step
# Epoch 43/50
# 39/39 - 2s - loss: 327.6617 - 2s/epoch - 44ms/step
# Epoch 44/50
# 39/39 - 2s - loss: 283.0969 - 2s/epoch - 46ms/step
# Epoch 45/50
# 39/39 - 2s - loss: 276.3414 - 2s/epoch - 47ms/step
# Epoch 46/50
# 39/39 - 2s - loss: 262.9718 - 2s/epoch - 60ms/step
# Epoch 47/50
# 39/39 - 3s - loss: 251.4153 - 3s/epoch - 67ms/step
# Epoch 48/50
# 39/39 - 2s - loss: 246.9297 - 2s/epoch - 45ms/step
# Epoch 49/50
# 39/39 - 2s - loss: 258.7422 - 2s/epoch - 40ms/step
# Epoch 50/50
# 39/39 - 2s - loss: 242.5244 - 2s/epoch - 46ms/step

# %%
y_pred = model.predict(X_test_predict)
# Out:
# 27/27 [==============================] - 1s 9ms/step

# %%
print(y_pred.shape)
# Out:
# (841, 1)

# %%
print(y_pred)
# Out:
# [[ 30.792805]
#  [ 33.200584]
#  [ 36.07381 ]
#  [ 38.838585]
#  [ 40.58368 ]
#  [ 41.942276]
#  [ 42.73035 ]
#  [ 41.66078 ]
#  [ 38.57116 ]
#  [ 39.28619 ]
#  [ 39.426914]
#  [ 38.153316]
#  [ 39.4641  ]
#  [ 32.371864]
#  [ 31.73092 ]
#  [ 30.836607]
#  [ 31.509523]
#  [ 31.129025]
#  [ 30.909231]
#  [ 29.25108 ]
#  [ 30.43641 ]
#  [ 32.19032 ]
#  [ 33.674244]
#  [ 33.632946]
#  [ 34.786774]
#  [ 37.938103]
#  [ 40.464928]
#  [ 45.21929 ]
#  [ 46.96033 ]
#  [ 46.646976]
#  [ 48.257015]
#  [ 48.426064]
#  [ 49.508377]
#  [ 49.59081 ]
#  [ 52.11965 ]
#  [ 54.038208]
#  [ 54.176212]
#  [ 53.67651 ]
#  [ 50.99277 ]
#  [ 49.28097 ]
#  [ 45.186108]
#  [ 42.44912 ]
#  [ 40.769386]
#  [ 38.455864]
#  [ 38.400497]
#  [ 36.763447]
#  [ 39.144768]
#  [ 41.486183]
#  [ 42.998093]
#  [ 48.140965]
#  [ 54.315025]
#  [ 56.474697]
#  [ 56.795513]
#  [ 53.97059 ]
#  [ 53.91661 ]
#  [ 52.273712]
#  [ 53.042587]
#  [ 54.188637]
#  [ 55.23135 ]
#  [ 55.956814]
#  [ 51.37272 ]
#  [ 49.157345]
#  [ 48.708668]
#  [ 47.741947]
#  [ 47.00564 ]
#  [ 39.852665]
#  [ 36.485252]
#  [ 30.23487 ]
#  [ 31.1251  ]
#  [ 32.100475]
#  [ 35.373287]
#  [ 37.85079 ]
#  [ 37.279922]
#  [ 41.458767]
#  [ 42.87788 ]
#  [ 45.20882 ]
#  [ 47.091137]
#  [ 48.0202  ]
#  [ 46.30005 ]
#  [ 47.199177]
#  [ 48.34133 ]
#  [ 49.16181 ]
#  [ 48.25958 ]
#  [ 46.232735]
#  [ 42.85009 ]
#  [ 44.458946]
#  [ 42.755043]
#  [ 38.85825 ]
#  [ 37.56214 ]
#  [ 37.973644]
#  [ 37.716904]
#  [ 38.93574 ]
#  [ 41.35185 ]
#  [ 43.197437]
#  [ 42.85002 ]
#  [ 44.66654 ]
#  [ 45.718727]
#  [ 45.61706 ]
#  [ 46.43498 ]
#  [ 45.84203 ]
#  [ 45.36455 ]
#  [ 47.88105 ]
#  [ 50.49058 ]
#  [ 50.66736 ]
#  [ 48.814472]
#  [ 46.099827]
#  [ 44.807278]
#  [ 43.521503]
#  [ 40.169895]
#  [ 35.918053]
#  [ 36.71322 ]
#  [ 35.76816 ]
#  [ 36.9005  ]
#  [ 37.966137]
#  [ 38.219673]
#  [ 37.726574]
#  [ 37.44829 ]
#  [ 37.100586]
#  [ 35.482162]
#  [ 34.543297]
#  [ 33.91326 ]
#  [ 32.2015  ]
#  [ 33.494305]
#  [ 34.003098]
#  [ 33.98355 ]
#  [ 33.161087]
#  [ 33.633263]
#  [ 33.49043 ]
#  [ 33.027782]
#  [ 31.036963]
#  [ 29.271473]
#  [ 27.917534]
#  [ 28.618467]
#  [ 29.706947]
#  [ 30.133463]
#  [ 30.543016]
#  [ 31.083626]
#  [ 31.162315]
#  [ 30.359938]
#  [ 30.3385  ]
#  [ 30.335922]
#  [ 31.20411 ]
#  [ 30.996124]
#  [ 31.284296]
#  [ 35.556587]
#  [ 37.854214]
#  [ 39.46173 ]
#  [ 36.50534 ]
#  [ 37.228207]
#  [ 40.92422 ]
#  [ 39.06876 ]
#  [ 42.109432]
#  [ 43.755737]
#  [ 46.17595 ]
#  [ 47.882256]
#  [ 45.68048 ]
#  [ 43.811703]
#  [ 37.227913]
#  [ 38.876205]
#  [ 40.056686]
#  [ 40.45694 ]
#  [ 39.088543]
#  [ 38.026276]
#  [ 35.538967]
#  [ 33.383984]
#  [ 32.174145]
#  [ 30.46543 ]
#  [ 28.332283]
#  [ 29.097225]
#  [ 29.351202]
#  [ 31.237253]
#  [ 32.86329 ]
#  [ 34.113346]
#  [ 34.982857]
#  [ 34.819324]
#  [ 36.134537]
#  [ 38.58871 ]
#  [ 40.39642 ]
#  [ 41.05354 ]
#  [ 41.7478  ]
#  [ 39.468807]
#  [ 37.19395 ]
#  [ 36.514286]
#  [ 32.82383 ]
#  [ 32.031387]
#  [ 32.822994]
#  [ 32.955036]
#  [ 31.800695]
#  [ 33.536186]
#  [ 34.411674]
#  [ 33.88331 ]
#  [ 34.684803]
#  [ 33.618237]
#  [ 31.212168]
#  [ 32.779533]
#  [ 34.258648]
#  [ 35.594353]
#  [ 35.09948 ]
#  [ 34.72549 ]
#  [ 33.99714 ]
#  [ 33.722652]
#  [ 31.201471]
#  [ 30.773287]
#  [ 30.024874]
#  [ 29.28112 ]
#  [ 28.634302]
#  [ 28.261414]
#  [ 28.320711]
#  [ 27.721952]
#  [ 27.721952]
#  [ 27.721952]
#  [ 27.721952]
#  [ 27.721952]
#  [ 27.721952]
#  [ 27.721952]
#  [ 29.203081]
#  [ 30.436693]
#  [ 31.752523]
#  [ 33.250484]
#  [ 34.75814 ]
#  [ 36.228016]
#  [ 37.249798]
#  [ 39.824432]
#  [ 42.00224 ]
#  [ 43.987595]
#  [ 45.609695]
#  [ 46.537807]
#  [ 46.145943]
#  [ 45.69668 ]
#  [ 45.95436 ]
#  [ 47.75654 ]
#  [ 48.040382]
#  [ 44.35379 ]
#  [ 43.081734]
#  [ 41.126453]
#  [ 40.74031 ]
#  [ 38.182575]
#  [ 38.388535]
#  [ 34.69987 ]
#  [ 34.825874]
#  [ 36.37213 ]
#  [ 38.795425]
#  [ 35.28025 ]
#  [ 35.64444 ]
#  [ 39.076244]
#  [ 38.13193 ]
#  [ 40.018375]
#  [ 36.359013]
#  [ 36.344276]
#  [ 38.504616]
#  [ 37.96304 ]
#  [ 39.718964]
#  [ 39.248886]
#  [ 39.72536 ]
#  [ 35.565807]
#  [ 35.431316]
#  [ 34.260643]
#  [ 34.260643]
#  [ 34.260643]
#  [ 34.260643]
#  [ 34.260643]
#  [ 34.260643]
#  [ 34.260643]
#  [ 34.260643]
#  [ 34.2611  ]
#  [ 34.26645 ]
#  [ 33.706673]
#  [ 33.308266]
#  [ 33.85708 ]
#  [ 33.656788]
#  [ 34.66076 ]
#  [ 35.995296]
#  [ 37.006985]
#  [ 36.96218 ]
#  [ 36.615967]
#  [ 35.903053]
#  [ 35.959393]
#  [ 34.126873]
#  [ 35.73618 ]
#  [ 35.933697]
#  [ 33.801037]
#  [ 35.335457]
#  [ 37.775032]
#  [ 37.856255]
#  [ 37.06242 ]
#  [ 38.42927 ]
#  [ 36.79564 ]
#  [ 36.643238]
#  [ 37.206787]
#  [ 37.040615]
#  [ 35.071056]
#  [ 35.466694]
#  [ 34.38587 ]
#  [ 34.612354]
#  [ 34.56367 ]
#  [ 38.04249 ]
#  [ 39.586506]
#  [ 43.571613]
#  [ 48.24501 ]
#  [ 52.60646 ]
#  [ 55.69342 ]
#  [ 56.958908]
#  [ 56.706028]
#  [ 54.469788]
#  [ 55.163315]
#  [ 56.107117]
#  [ 55.50137 ]
#  [ 72.55978 ]
#  [ 73.34279 ]
#  [ 70.039925]
#  [ 65.73879 ]
#  [ 64.34452 ]
#  [ 62.043404]
#  [ 61.759415]
#  [ 61.900562]
#  [ 61.758896]
#  [ 65.60092 ]
#  [ 71.27108 ]
#  [ 71.764404]
#  [ 83.72365 ]
#  [ 84.01025 ]
#  [ 92.44365 ]
#  [ 76.21355 ]
#  [ 70.99876 ]
#  [ 73.0031  ]
#  [ 83.25071 ]
#  [ 82.8805  ]
#  [ 77.31531 ]
#  [ 66.42473 ]
#  [ 53.82323 ]
#  [ 46.819637]
#  [ 44.512665]
#  [ 44.362133]
#  [ 43.893204]
#  [ 47.434414]
#  [ 51.178104]
#  [ 47.297836]
#  [ 46.3263  ]
#  [ 49.42052 ]
#  [ 53.441822]
#  [ 54.407677]
#  [ 53.71048 ]
#  [ 56.70944 ]
#  [ 56.82452 ]
#  [ 59.290188]
#  [ 57.268265]
#  [ 58.485416]
#  [ 58.328655]
#  [ 53.753292]
#  [ 54.38525 ]
#  [ 49.83889 ]
#  [ 49.57194 ]
#  [ 51.688587]
#  [ 51.4957  ]
#  [ 54.18165 ]
#  [ 51.277763]
#  [ 61.05959 ]
#  [ 64.20294 ]
#  [ 62.323418]
#  [ 57.57832 ]
#  [ 52.25028 ]
#  [ 51.261307]
#  [ 48.244278]
#  [ 52.08467 ]
#  [ 54.791245]
#  [ 55.043427]
#  [ 57.726723]
#  [ 57.934887]
#  [ 53.45606 ]
#  [ 57.771065]
#  [ 58.23865 ]
#  [ 58.289417]
#  [ 54.03134 ]
#  [ 53.77561 ]
#  [ 52.218376]
#  [ 50.744053]
#  [ 56.520634]
#  [ 55.334373]
#  [ 53.100315]
#  [ 50.302124]
#  [ 47.826576]
#  [ 47.484   ]
#  [ 46.779415]
#  [ 53.2858  ]
#  [ 57.369896]
#  [ 72.4913  ]
#  [ 73.73939 ]
#  [ 87.51001 ]
#  [ 81.47267 ]
#  [ 70.60954 ]
#  [ 64.33137 ]
#  [ 66.51079 ]
#  [ 62.692005]
#  [ 60.23772 ]
#  [ 54.24069 ]
#  [ 52.589195]
#  [ 51.154434]
#  [ 50.100994]
#  [ 48.883034]
#  [ 47.91024 ]
#  [ 51.0392  ]
#  [ 49.988396]
#  [ 49.43946 ]
#  [ 57.75243 ]
#  [ 57.75243 ]
#  [ 57.521824]
#  [ 57.118877]
#  [ 56.4497  ]
#  [ 55.59539 ]
#  [ 54.595486]
#  [ 53.201347]
#  [ 51.500957]
#  [ 49.271244]
#  [ 46.620842]
#  [ 43.573387]
#  [ 40.06642 ]
#  [ 36.49253 ]
#  [ 36.321774]
#  [ 36.10167 ]
#  [ 36.741074]
#  [ 36.66902 ]
#  [ 36.27297 ]
#  [ 35.484077]
#  [ 35.421608]
#  [ 36.306908]
#  [ 35.867237]
#  [ 34.017338]
#  [ 31.445892]
#  [ 29.085373]
#  [ 30.052694]
#  [ 30.710629]
#  [ 32.167057]
#  [ 33.536404]
#  [ 33.129337]
#  [ 33.297012]
#  [ 32.990982]
#  [ 32.98979 ]
#  [ 32.69245 ]
#  [ 32.173622]
#  [ 29.444168]
#  [ 28.431591]
#  [ 26.463825]
#  [ 24.238976]
#  [ 22.361235]
#  [ 22.02998 ]
#  [ 21.672022]
#  [ 21.73045 ]
#  [ 21.436916]
#  [ 20.759497]
#  [ 20.542244]
#  [ 20.00128 ]
#  [ 19.584303]
#  [ 19.093987]
#  [ 19.005081]
#  [ 19.008547]
#  [ 19.091604]
#  [ 19.355356]
#  [ 19.7382  ]
#  [ 20.18302 ]
#  [ 20.688316]
#  [ 21.137098]
#  [ 21.736767]
#  [ 22.236029]
#  [ 23.178616]
#  [ 23.334427]
#  [ 24.145397]
#  [ 24.678131]
#  [ 25.724468]
#  [ 27.278496]
#  [ 29.2975  ]
#  [ 32.18857 ]
#  [ 35.744774]
#  [ 40.20495 ]
#  [ 40.290966]
#  [ 40.402794]
#  [ 40.591103]
#  [ 40.65412 ]
#  [ 40.841347]
#  [ 40.86771 ]
#  [ 40.905975]
#  [ 40.95234 ]
#  [ 41.01308 ]
#  [ 41.132076]
#  [ 41.23578 ]
#  [ 41.30668 ]
#  [ 41.28311 ]
#  [ 41.812542]
#  [ 40.365738]
#  [ 39.127945]
#  [ 38.15516 ]
#  [ 37.139393]
#  [ 35.85293 ]
#  [ 34.38104 ]
#  [ 32.883816]
#  [ 31.242935]
#  [ 29.73493 ]
#  [ 28.543324]
#  [ 28.884516]
#  [ 28.00348 ]
#  [ 27.729553]
#  [ 27.366293]
#  [ 26.896204]
#  [ 27.499393]
#  [ 27.554245]
#  [ 27.681902]
#  [ 28.054676]
#  [ 28.714115]
#  [ 29.570148]
#  [ 30.961374]
#  [ 33.013123]
#  [ 35.456955]
#  [ 38.31801 ]
#  [ 41.936493]
#  [ 45.93668 ]
#  [ 48.450478]
#  [ 53.53327 ]
#  [ 57.349045]
#  [ 59.31992 ]
#  [ 61.880493]
#  [ 62.20626 ]
#  [ 62.41948 ]
#  [ 61.507343]
#  [ 60.156994]
#  [ 57.460217]
#  [ 50.62668 ]
#  [ 41.309105]
#  [ 32.501667]
#  [ 32.226673]
#  [ 31.924852]
#  [ 33.73443 ]
#  [ 34.393696]
#  [ 37.490517]
#  [ 43.506733]
#  [ 49.911793]
#  [ 55.305645]
#  [ 59.96176 ]
#  [ 63.191696]
#  [ 60.865704]
#  [ 57.56912 ]
#  [ 55.59656 ]
#  [ 54.16616 ]
#  [ 50.452236]
#  [ 44.838284]
#  [ 38.305256]
#  [ 34.1108  ]
#  [ 33.95516 ]
#  [ 34.431755]
#  [ 35.17585 ]
#  [ 37.145073]
#  [ 39.039913]
#  [ 40.41961 ]
#  [ 42.49322 ]
#  [ 43.131657]
#  [ 43.187416]
#  [ 44.29816 ]
#  [ 44.52284 ]
#  [ 44.24766 ]
#  [ 46.187325]
#  [ 46.73319 ]
#  [ 42.518158]
#  [ 44.477325]
#  [ 43.014465]
#  [ 43.411617]
#  [ 43.668644]
#  [ 43.67358 ]
#  [ 43.46936 ]
#  [ 47.694668]
#  [ 51.93829 ]
#  [ 55.805912]
#  [ 58.360992]
#  [ 56.235798]
#  [ 55.76652 ]
#  [ 51.453987]
#  [ 56.736794]
#  [ 54.406994]
#  [ 55.769176]
#  [ 54.244453]
#  [ 53.894253]
#  [ 54.755806]
#  [ 54.01885 ]
#  [ 52.943645]
#  [ 57.036957]
#  [ 61.943798]
#  [ 67.00943 ]
#  [ 72.13049 ]
#  [ 72.45659 ]
#  [ 72.38717 ]
#  [ 76.81865 ]
#  [ 82.08452 ]
#  [ 93.80391 ]
#  [113.87029 ]
#  [113.71551 ]
#  [ 97.05695 ]
#  [ 76.58013 ]
#  [ 67.73653 ]
#  [ 60.66539 ]
#  [ 66.04319 ]
#  [ 63.680687]
#  [ 59.240707]
#  [ 46.388523]
#  [ 39.51143 ]
#  [ 38.102467]
#  [ 38.103218]
#  [ 38.408035]
#  [ 38.28727 ]
#  [ 38.06485 ]
#  [ 40.077232]
#  [ 42.8188  ]
#  [ 43.05084 ]
#  [ 44.036293]
#  [ 44.677547]
#  [ 43.438927]
#  [ 40.054928]
#  [ 36.65402 ]
#  [ 32.76804 ]
#  [ 28.50931 ]
#  [ 26.182537]
#  [ 26.052412]
#  [ 25.988787]
#  [ 26.312971]
#  [ 27.200588]
#  [ 28.27654 ]
#  [ 29.20037 ]
#  [ 30.408802]
#  [ 32.228764]
#  [ 34.22894 ]
#  [ 39.65327 ]
#  [ 41.896564]
#  [ 42.529324]
#  [ 46.27792 ]
#  [ 51.809822]
#  [ 53.861504]
#  [ 53.639305]
#  [ 53.018555]
#  [ 51.436565]
#  [ 50.66483 ]
#  [ 48.580055]
#  [ 48.321644]
#  [ 46.74256 ]
#  [ 47.42279 ]
#  [ 48.75714 ]
#  [ 46.5204  ]
#  [ 44.323296]
#  [ 49.274353]
#  [ 47.546173]
#  [ 45.394398]
#  [ 41.427097]
#  [ 40.453705]
#  [ 38.322254]
#  [ 39.681755]
#  [ 41.589394]
#  [ 48.328487]
#  [ 59.041153]
#  [ 59.200336]
#  [ 57.994186]
#  [ 54.65223 ]
#  [ 54.19217 ]
#  [ 54.128468]
#  [ 51.926483]
#  [ 49.398987]
#  [ 47.684093]
#  [ 43.893963]
#  [ 39.135605]
#  [ 39.291386]
#  [ 38.799477]
#  [ 34.626144]
#  [ 34.366116]
#  [ 31.603327]
#  [ 30.471428]
#  [ 31.390535]
#  [ 32.773117]
#  [ 37.2983  ]
#  [ 41.205727]
#  [ 43.51125 ]
#  [ 43.138767]
#  [ 40.87572 ]
#  [ 42.493736]
#  [ 44.59404 ]
#  [ 43.547592]
#  [ 42.40967 ]
#  [ 41.312992]
#  [ 39.633915]
#  [ 38.956226]
#  [ 36.050003]
#  [ 32.47068 ]
#  [ 31.392878]
#  [ 30.153004]
#  [ 29.515718]
#  [ 28.73515 ]
#  [ 25.293768]
#  [ 25.49086 ]
#  [ 26.75747 ]
#  [ 27.089695]
#  [ 28.304747]
#  [ 28.641712]
#  [ 28.786373]
#  [ 30.332575]
#  [ 31.72338 ]
#  [ 33.163105]
#  [ 33.672222]
#  [ 34.27324 ]
#  [ 36.270096]]

# %%
for prediction in y_pred:
    last_value = prediction[-1]  # Assuming the last column is the target variable
    print(last_value)
# Out:
# 30.792805
# 33.200584
# 36.07381
# 38.838585
# 40.58368
# 41.942276
# 42.73035
# 41.66078
# 38.57116
# 39.28619
# 39.426914
# 38.153316
# 39.4641
# 32.371864
# 31.73092
# 30.836607
# 31.509523
# 31.129025
# 30.909231
# 29.25108
# 30.43641
# 32.19032
# 33.674244
# 33.632946
# 34.786774
# 37.938103
# 40.464928
# 45.21929
# 46.96033
# 46.646976
# 48.257015
# 48.426064
# 49.508377
# 49.59081
# 52.11965
# 54.038208
# 54.176212
# 53.67651
# 50.99277
# 49.28097
# 45.186108
# 42.44912
# 40.769386
# 38.455864
# 38.400497
# 36.763447
# 39.144768
# 41.486183
# 42.998093
# 48.140965
# 54.315025
# 56.474697
# 56.795513
# 53.97059
# 53.91661
# 52.273712
# 53.042587
# 54.188637
# 55.23135
# 55.956814
# 51.37272
# 49.157345
# 48.708668
# 47.741947
# 47.00564
# 39.852665
# 36.485252
# 30.23487
# 31.1251
# 32.100475
# 35.373287
# 37.85079
# 37.279922
# 41.458767
# 42.87788
# 45.20882
# 47.091137
# 48.0202
# 46.30005
# 47.199177
# 48.34133
# 49.16181
# 48.25958
# 46.232735
# 42.85009
# 44.458946
# 42.755043
# 38.85825
# 37.56214
# 37.973644
# 37.716904
# 38.93574
# 41.35185
# 43.197437
# 42.85002
# 44.66654
# 45.718727
# 45.61706
# 46.43498
# 45.84203
# 45.36455
# 47.88105
# 50.49058
# 50.66736
# 48.814472
# 46.099827
# 44.807278
# 43.521503
# 40.169895
# 35.918053
# 36.71322
# 35.76816
# 36.9005
# 37.966137
# 38.219673
# 37.726574
# 37.44829
# 37.100586
# 35.482162
# 34.543297
# 33.91326
# 32.2015
# 33.494305
# 34.003098
# 33.98355
# 33.161087
# 33.633263
# 33.49043
# 33.027782
# 31.036963
# 29.271473
# 27.917534
# 28.618467
# 29.706947
# 30.133463
# 30.543016
# 31.083626
# 31.162315
# 30.359938
# 30.3385
# 30.335922
# 31.20411
# 30.996124
# 31.284296
# 31.463951
# 30.453402
# 29.263494
# 28.227467
# 27.832392
# 26.18001
# 26.181728
# 25.7111
# 25.129324
# 25.544834
# 25.5698
# 25.990835
# 26.19674
# 26.934452
# 27.929592
# 26.524557
# 26.781958
# 26.90446
# 26.920425
# 26.740946
# 26.69417
# 26.532501
# 26.213898
# 25.823215
# 25.21469
# 24.116344
# 24.083775
# 23.763231
# 23.214539
# 23.117409
# 21.301783
# 22.109854
# 22.835318
# 23.396397
# 24.095274
# 24.487505
# 25.111944
# 24.936768
# 24.237959
# 23.212431
# 22.598728
# 21.97277
# 21.375656
# 21.05976
# 20.750925
# 20.318495
# 19.12048
# 19.353506
# 27.554245
# 27.681902
# 28.054676
# 28.714115
# 29.570148
# 30.961374
# 33.013123
# 35.456955
# 38.31801
# 41.936493
# 45.93668
# 48.450478
# 53.53327
# 57.349045
# 59.31992
# 61.880493
# 62.20626
# 62.41948
# 61.507343
# 60.156994
# 57.460217
# 50.62668
# 41.309105
# 32.501667
# 32.226673
# 31.924852
# 33.73443
# 34.393696
# 37.490517
# 43.506733
# 49.911793
# 55.305645
# 59.96176
# 63.191696
# 60.865704
# 57.56912
# 55.59656
# 54.16616
# 50.452236
# 44.838284
# 38.305256
# 34.1108
# 33.95516
# 34.431755
# 35.17585
# 37.145073
# 39.039913
# 40.41961
# 42.49322
# 43.131657
# 43.187416
# 44.29816
# 44.52284
# 44.24766
# 46.187325
# 46.73319
# 42.518158
# 44.477325
# 43.014465
# 43.411617
# 43.668644
# 43.67358
# 43.46936
# 47.694668
# 51.93829
# 55.805912
# 58.360992
# 56.235798
# 55.76652
# 51.453987
# 56.736794
# 54.406994
# 55.769176
# 54.244453
# 53.894253
# 54.755806
# 54.01885
# 52.943645
# 57.036957
# 61.943798
# 67.00943
# 72.13049
# 72.45659
# 72.38717
# 76.81865
# 82.08452
# 93.80391
# 113.87029
# 113.71551
# 97.05695
# 76.58013
# 67.73653
# 60.66539
# 66.04319
# 63.680687
# 59.240707
# 46.388523
# 39.51143
# 38.102467
# 38.103218
# 38.408035
# 38.28727
# 38.06485
# 40.077232
# 42.8188
# 43.05084
# 44.036293
# 44.677547
# 43.438927
# 40.054928
# 36.65402
# 32.76804
# 28.50931
# 26.182537
# 26.052412
# 25.988787
# 26.312971
# 27.200588
# 28.27654
# 29.20037
# 30.408802
# 32.228764
# 34.22894
# 39.65327
# 41.896564
# 42.529324
# 46.27792
# 51.809822
# 53.861504
# 53.639305
# 53.018555
# 51.436565
# 50.66483
# 48.580055
# 48.321644
# 46.74256
# 47.42279
# 48.75714
# 46.5204
# 44.323296
# 49.274353
# 47.546173
# 45.394398
# 41.427097
# 40.453705
# 38.322254
# 39.681755
# 41.589394
# 48.328487
# 59.041153
# 59.200336
# 57.994186
# 54.65223
# 54.19217
# 54.128468
# 51.926483
# 49.398987
# 47.684093
# 43.893963
# 39.135605
# 39.291386
# 38.799477
# 34.626144
# 34.366116
# 31.603327
# 30.471428
# 31.390535
# 32.773117
# 37.2983
# 41.205727
# 43.51125
# 43.138767
# 40.87572
# 42.493736
# 44.59404
# 43.547592
# 42.40967
# 41.312992
# 39.633915
# 38.956226
# 36.050003
# 32.47068
# 31.392878
# 30.153004
# 29.515718
# 28.73515
# 25.293768
# 25.49086
# 26.75747
# 27.089695
# 28.304747
# 28.641712
# 28.786373
# 30.332575
# 31.72338
# 33.163105
# 33.672222
# 34.27324
# 36.270096

# %%
print(y_test.shape)
# Out:
# (858, 1)

# %%
print(y_test.shape)
# Out:
# (858, 1)

# %%
y_test = y_test[n_steps_in: -n_steps_out]

# %%
print(y_test.shape)
# Out:
# (841, 1)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

mean_squared_error(y_test, y_pred)
# Out:
# 298.84945280370454

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

mean_absolute_error(y_test, y_pred)
# Out:
# 13.55647633900682
